# %%
import seaborn as sns
import matplotlib.pyplot as plt
import pandas as pd

# %%
df=pd.read_csv("../data/nonca_kmers.csv")
test=df[df['count'] != 1]
df
# Out:
#       number                   kmer  count
# 0          1  AAAAATTTTTTTTTTTTTTTT     23
# 1          2  AAAAAATGTTCTTTAGGAGTT      1
# 2          3  AAAAAAGACCTGGTTACTTCT      1
# 3          4  AAAAACAGGATTTTTTTTATG      1
# 4          5  AAAAACGATCACACGACCCTG      1
# ...      ...                    ...    ...
# 5911    5912  AAAAAAATTTACAAACACACG      1
# 5912    5913  AAAAAATTGTGAACTAGTCAG      2
# 5913    5914  AAAAAGACTAGCTTACACTCA      1
# 5914    5915  AAAAAGACTAGTCTAAAATCA      1
# 5915    5916  AAAAAGACTAGTGTACAATCA      1
#
# [5916 rows x 3 columns]

# %%
df=df.groupby(['count']).count()

# %%
df
# Out:
#        number  kmer
# count
# 1        4415  4415
# 2         727   727
# 3         270   270
# 4         157   157
# 5          85    85
# 6          60    60
# 7          27    27
# 8          28    28
# 9          25    25
# 10         23    23
# 11          8     8
# 12          6     6
# 13         11    11
# 14         12    12
# 15          9     9
# 16          4     4
# 17          9     9
# 18          2     2
# 19          2     2
# 20          2     2
# 21          4     4
# 22          7     7
# 23         10    10
# 24          2     2
# 25          4     4
# 26          1     1
# 27          2     2
# 32          2     2
# 33          1     1
# 34          1     1

# %%
ax=sns.lineplot(data=df, x="count",y="number")
ax.set_ylabel("Frequency")
ax.set_xlabel("Kmer Counts")
sns.despine()
plt.savefig('line.png',bbox_inches ="tight",dpi=300)

# %%
sns.set_context("paper")
sns.color_palette("pastel")
sns.set(rc={'figure.figsize':(10,10)})
sns.set_style("white")
ax=sns.histplot(df,x="count",kde=True)
ax.set_ylabel("Frequency")
ax.set_xlabel("Kmer Counts")
sns.despine()
plt.savefig('hist.png',bbox_inches ="tight",dpi=300)

# %%
sns.set_context("paper")
sns.color_palette("pastel")
sns.set(rc={'figure.figsize':(10,10)})
sns.set_style("white")
ax=sns.histplot(test,kde=True)
ax.set_ylabel("Count")
ax.set_xlabel("Frequency of Counts")
sns.despine()
